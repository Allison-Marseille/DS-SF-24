# %%
import pandas as pd
#import my dataset
data = pd.read_csv('C:\Users\Allison\Documents\GitHub\GeneralAssembly\DS-SF-24\Allison Marseille Final Project\ks_school_wellness_policies_clean_csv.csv')

# %%
#explore the dataset
data.head()
# Out:
#     District Name  District Number  Year elem_nutr_gen_atm mid_nutr_gen_atm  \
# 0         Abilene              435  2010                B+               B+
# 1         Andover              385  2010                B+               B+
# 2  Anthony-Harper              361  2010                B+                B
# 3   Arkansas City              470  2010                B+               B+
# 4        Atchison              409  2010                B+               B+
#
#   hs_nutr_gen_atm elem_nutr_bkfst mid_nutr_bkfst hs_nutr_bkfst  \
# 0              B+               E              E            E-
# 1              A-              E+             E+            E+
# 2              A-              E-             E-            E-
# 3              A-               A              A             A
# 4              B+              E-              E             E
#
#   elem_nutr_lunch      ...       6_mean_edfa_math 6_se_edfa_math  \
# 0               E      ...               0.073637       0.060356
# 1              E-      ...               0.431682       0.043095
# 2             NaN      ...              -0.245087       0.103889
# 3               A      ...              -0.070124       0.065053
# 4              E-      ...               0.015809       0.094373
#
#   7_mean_edfa_ela 7_se_edfa_ela 7_mean_edfa_math 7_se_edfa_math  \
# 0        0.175573      0.072037         0.348184       0.074271
# 1        0.668914      0.067172         0.345945       0.050462
# 2       -0.204939      0.111004         0.210916       0.144562
# 3        0.005581      0.081045         0.019761       0.068405
# 4       -0.211118      0.099261         0.006293       0.098217
#
#   8_mean_edfa_ela 8_se_edfa_ela 8_mean_edfa_math 8_se_edfa_math
# 0       -0.064195      0.076141         0.252673       0.072944
# 1        0.509893      0.054946         0.234616       0.043001
# 2       -0.404794      0.091061        -0.274760       0.101217
# 3       -0.102936      0.059151         0.016154       0.064384
# 4       -0.002524      0.093781         0.019301       0.090991
#
# [5 rows x 94 columns]

# %%
len(data)
# Out:
# 251

# %%
my_list = data.columns.values
for i in my_list:
    print i
# Out:
# District Name
# District Number
# Year
# elem_nutr_gen_atm
# mid_nutr_gen_atm
# hs_nutr_gen_atm
# elem_nutr_bkfst
# mid_nutr_bkfst
# hs_nutr_bkfst
# elem_nutr_lunch
# mid_nutr_lunch
# hs_nutr_lunch
# elem_nutr_a_la_carte
# mid_nutr_a_la_carte
# hs_nutr_a_la_carte
# elem_nutr_vend
# mid_nutr_vend
# hs_nutr_vend
# elem_nutr_sch_store
# mid_nutr_sch_store
# hs_nutr_sch_store
# elem_nutr_sch_day
# mid_nutr_sch_day
# hs_nutr_sch_day
# elem_nutr_aft_sch_prog
# mid_nutr_aft_sch_prog
# hs_nutr_aft_sch_prog
# elem_ne_gen_guide_and_class
# mid_ne_gen_guide_and_class
# hs_ne_gen_guide_and_class
# elem_ne_cafeteria
# mid_ne_cafeteria
# hs_ne_cafeteria
# elem_ne_events_dur_sch_day
# mid_ne_events_dur_sch_day
# hs_ne_events_dur_sch_day
# elem_ne_aft_sch_prog
# mid_ne_aft_sch_prog
# hs_ne_aft_sch_prog
# elem_ne_fam_comm
# mid_ne_fam_comm
# hs_ne_fam_comm
# elem_ne_staff_well
# mid_ne_staff_well
# hs_ne_staff_well
# elem_pa_gen_guide_pe_class
# mid_pa_gen_guide_pe_class
# hs_pa_gen_guide_pe_class
# elem_pa_thru_day
# mid_pa_thru_day
# hs_pa_thru_day
# elem_pa_punish
# mid_pa_punish
# hs_pa_punish
# elem_pa_recess
# mid_pa_recess
# hs_pa_recess
# elem_pa_bef_aft_sch
# mid_pa_bef_aft_sch
# hs_pa_bef_aft_sch
# elem_pa_fam_comm
# mid_pa_fam_comm
# hs_pa_fam_comm
# Notes
# leaid
# leaname
# fips
# stateabb
# year
# grade
# 3_mean_edfa_ela
# 3_se_edfa_ela
# 3_mean_edfa_math
# 3_se_edfa_math
# 4_mean_edfa_ela
# 4_se_edfa_ela
# 4_mean_edfa_math
# 4_se_edfa_math
# 5_mean_edfa_ela
# 5_se_edfa_ela
# 5_mean_edfa_math
# 5_se_edfa_math
# 6_mean_edfa_ela
# 6_se_edfa_ela
# 6_mean_edfa_math
# 6_se_edfa_math
# 7_mean_edfa_ela
# 7_se_edfa_ela
# 7_mean_edfa_math
# 7_se_edfa_math
# 8_mean_edfa_ela
# 8_se_edfa_ela
# 8_mean_edfa_math
# 8_se_edfa_math

# %%
data.describe()
# Out:
# C:\Users\Allison\Anaconda2\lib\site-packages\numpy\lib\function_base.py:3823: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#        District Number    Year  Notes         leaid   fips    year  \
# count       251.000000   251.0    0.0  2.510000e+02  251.0   251.0
# mean        352.549801  2010.0    NaN  2.007587e+06   20.0  2010.0
# std          99.059904     0.0    NaN  3.439995e+03    0.0     0.0
# min         101.000000  2010.0    NaN  2.000001e+06   20.0  2010.0
# 25%         270.500000  2010.0    NaN  2.005160e+06   20.0  2010.0
# 50%         358.000000  2010.0    NaN  2.007740e+06   20.0  2010.0
# 75%         437.000000  2010.0    NaN  2.010425e+06   20.0  2010.0
# max         512.000000  2010.0    NaN  2.013110e+06   20.0  2010.0
#
#             grade  3_mean_edfa_ela  3_se_edfa_ela  3_mean_edfa_math  \
# count  251.000000       220.000000     220.000000        220.000000
# mean     3.318725         0.060373       0.128779          0.040563
# std      0.996999         0.289454       0.050048          0.307185
# min      3.000000        -0.792894       0.016431         -0.734705
# 25%      3.000000              NaN            NaN               NaN
# 50%      3.000000              NaN            NaN               NaN
# 75%      3.000000              NaN            NaN               NaN
# max      8.000000         0.889860       0.231707          0.745791
#
#             ...        6_mean_edfa_math  6_se_edfa_math  7_mean_edfa_ela  \
# count       ...              219.000000      219.000000       226.000000
# mean        ...                0.054989        0.119010         0.012370
# std         ...                0.343802        0.043349         0.291672
# min         ...               -0.827827        0.015950        -0.748603
# 25%         ...                     NaN             NaN              NaN
# 50%         ...                     NaN             NaN              NaN
# 75%         ...                     NaN             NaN              NaN
# max         ...                0.897513        0.204389         0.996598
#
#        7_se_edfa_ela  7_mean_edfa_math  7_se_edfa_math  8_mean_edfa_ela  \
# count     226.000000        226.000000      226.000000       228.000000
# mean        0.131012          0.019314        0.124437         0.049950
# std         0.049684          0.360863        0.049426         0.280918
# min         0.018052         -0.795048        0.018335        -0.691615
# 25%              NaN               NaN             NaN              NaN
# 50%              NaN               NaN             NaN              NaN
# 75%              NaN               NaN             NaN              NaN
# max         0.228141          1.454810        0.261316         1.058775
#
#        8_se_edfa_ela  8_mean_edfa_math  8_se_edfa_math
# count     228.000000        229.000000      229.000000
# mean        0.128113          0.037101        0.123538
# std         0.048205          0.334971        0.047096
# min         0.018767         -0.802230        0.020203
# 25%              NaN               NaN             NaN
# 50%              NaN               NaN             NaN
# 75%              NaN               NaN             NaN
# max         0.252078          1.314681        0.241432
#
# [8 rows x 31 columns]

# %%
#delete columns I know I won't be using
del data['3_se_edfa_ela']
del data['3_se_edfa_math']
del data['4_se_edfa_ela']
del data['4_se_edfa_math']
del data['5_se_edfa_ela']
del data['5_se_edfa_math']
del data['6_se_edfa_ela']
del data['6_se_edfa_math']
del data['7_se_edfa_ela']
del data['7_se_edfa_math']
del data['8_se_edfa_ela']
del data['8_se_edfa_math']
del data['Notes']
del data['leaid']
del data['leaname']
del data['fips']
del data['stateabb']
del data['year']
del data['grade']
del data['District Number']
del data['Year']

#delete columns with greater than 15% missing observations (I did this in Excel. How to see all of data.describe?)
del data['mid_pa_recess']
del data['hs_pa_recess']
del data['elem_nutr_sch_store']
del data['hs_ne_aft_sch_prog']
del data['mid_ne_aft_sch_prog']
del data['elem_ne_aft_sch_prog']
del data['hs_nutr_aft_sch_prog']
del data['mid_nutr_aft_sch_prog']
del data['elem_nutr_aft_sch_prog']
del data['hs_nutr_sch_store']
del data['mid_nutr_sch_store']
del data['elem_nutr_vend']
del data['elem_nutr_a_la_carte']
del data['mid_nutr_a_la_carte']
del data['hs_nutr_a_la_carte']
del data['mid_nutr_vend']
del data['elem_pa_bef_aft_sch']
del data['mid_pa_bef_aft_sch']
del data['hs_pa_bef_aft_sch']

data.head()
# Out:
#     District Name elem_nutr_gen_atm mid_nutr_gen_atm hs_nutr_gen_atm  \
# 0         Abilene                B+               B+              B+
# 1         Andover                B+               B+              A-
# 2  Anthony-Harper                B+                B              A-
# 3   Arkansas City                B+               B+              A-
# 4        Atchison                B+               B+              B+
#
#   elem_nutr_bkfst mid_nutr_bkfst hs_nutr_bkfst elem_nutr_lunch mid_nutr_lunch  \
# 0               E              E            E-               E              E
# 1              E+             E+            E+              E-             E-
# 2              E-             E-            E-             NaN            NaN
# 3               A              A             A               A              A
# 4              E-              E             E              E-             E-
#
#   hs_nutr_lunch       ...        4_mean_edfa_ela 4_mean_edfa_math  \
# 0             E       ...              -0.012612        -0.200108
# 1            E-       ...               0.302901         0.341898
# 2           NaN       ...               0.089148         0.055699
# 3             A       ...              -0.153506        -0.016027
# 4            E-       ...              -0.406145        -0.616993
#
#   5_mean_edfa_ela 5_mean_edfa_math 6_mean_edfa_ela 6_mean_edfa_math  \
# 0        0.127019        -0.135540        0.126632         0.073637
# 1        0.533983         0.594967        0.435067         0.431682
# 2        0.107402         0.460087       -0.278540        -0.245087
# 3        0.000737         0.057150        0.008406        -0.070124
# 4       -0.196663        -0.194538        0.004002         0.015809
#
#   7_mean_edfa_ela 7_mean_edfa_math 8_mean_edfa_ela 8_mean_edfa_math
# 0        0.175573         0.348184       -0.064195         0.252673
# 1        0.668914         0.345945        0.509893         0.234616
# 2       -0.204939         0.210916       -0.404794        -0.274760
# 3        0.005581         0.019761       -0.102936         0.016154
# 4       -0.211118         0.006293       -0.002524         0.019301
#
# [5 rows x 54 columns]

# %%
#replace the wellness policy scores with numbers (Basic(B), Advanced(A), and Exemplary(E))
data.replace(to_replace = ('B-', 'B', 'B+', 'A-', 'A', 'A+', 'E-', 'E', 'E+'), value = (1, 2, 3, 4, 5, 6, 7, 8, 9), inplace = True)

data.head()
# Out:
#     District Name  elem_nutr_gen_atm  mid_nutr_gen_atm  hs_nutr_gen_atm  \
# 0         Abilene                3.0               3.0              3.0
# 1         Andover                3.0               3.0              4.0
# 2  Anthony-Harper                3.0               2.0              4.0
# 3   Arkansas City                3.0               3.0              4.0
# 4        Atchison                3.0               3.0              3.0
#
#    elem_nutr_bkfst  mid_nutr_bkfst  hs_nutr_bkfst  elem_nutr_lunch  \
# 0              8.0             8.0            7.0              8.0
# 1              9.0             9.0            9.0              7.0
# 2              7.0             7.0            7.0              NaN
# 3              5.0             5.0            5.0              5.0
# 4              7.0             8.0            8.0              7.0
#
#    mid_nutr_lunch  hs_nutr_lunch        ...         4_mean_edfa_ela  \
# 0             8.0            8.0        ...               -0.012612
# 1             7.0            7.0        ...                0.302901
# 2             NaN            NaN        ...                0.089148
# 3             5.0            5.0        ...               -0.153506
# 4             7.0            7.0        ...               -0.406145
#
#    4_mean_edfa_math  5_mean_edfa_ela  5_mean_edfa_math  6_mean_edfa_ela  \
# 0         -0.200108         0.127019         -0.135540         0.126632
# 1          0.341898         0.533983          0.594967         0.435067
# 2          0.055699         0.107402          0.460087        -0.278540
# 3         -0.016027         0.000737          0.057150         0.008406
# 4         -0.616993        -0.196663         -0.194538         0.004002
#
#    6_mean_edfa_math  7_mean_edfa_ela  7_mean_edfa_math  8_mean_edfa_ela  \
# 0          0.073637         0.175573          0.348184        -0.064195
# 1          0.431682         0.668914          0.345945         0.509893
# 2         -0.245087        -0.204939          0.210916        -0.404794
# 3         -0.070124         0.005581          0.019761        -0.102936
# 4          0.015809        -0.211118          0.006293        -0.002524
#
#    8_mean_edfa_math
# 0          0.252673
# 1          0.234616
# 2         -0.274760
# 3          0.016154
# 4          0.019301
#
# [5 rows x 54 columns]

# %%
#address missing values
#I'll try to use a regression model to predict missing values... dear God help us all... :)

len(data)
# Out:
# 251

# %%
data.describe()
# Out:
#        elem_nutr_gen_atm  mid_nutr_gen_atm  hs_nutr_gen_atm  elem_nutr_bkfst  \
# count         249.000000        240.000000       245.000000       244.000000
# mean            2.895582          2.904167         3.644898         7.020492
# std             0.306418          0.294978         0.683848         1.191357
# min             2.000000          2.000000         2.000000         3.000000
# 25%                  NaN               NaN              NaN              NaN
# 50%                  NaN               NaN              NaN              NaN
# 75%                  NaN               NaN              NaN              NaN
# max             3.000000          3.000000         4.000000         9.000000
#
#        mid_nutr_bkfst  hs_nutr_bkfst  elem_nutr_lunch  mid_nutr_lunch  \
# count      234.000000     231.000000       226.000000      218.000000
# mean         7.051282       7.025974         5.920354        6.087156
# std          1.217513       1.201166         1.443093        1.483153
# min          3.000000       3.000000         3.000000        3.000000
# 25%               NaN            NaN              NaN             NaN
# 50%               NaN            NaN              NaN             NaN
# 75%               NaN            NaN              NaN             NaN
# max          9.000000       9.000000         9.000000        9.000000
#
#        hs_nutr_lunch  hs_nutr_vend        ...         4_mean_edfa_ela  \
# count     224.000000    214.000000        ...              217.000000
# mean        6.151786      6.242991        ...                0.053719
# std         1.465354      1.716209        ...                0.298211
# min         3.000000      2.000000        ...               -0.769619
# 25%              NaN           NaN        ...                     NaN
# 50%              NaN           NaN        ...                     NaN
# 75%              NaN           NaN        ...                     NaN
# max         9.000000      9.000000        ...                1.099373
#
#        4_mean_edfa_math  5_mean_edfa_ela  5_mean_edfa_math  6_mean_edfa_ela  \
# count        216.000000       218.000000        218.000000       219.000000
# mean           0.030854         0.042776          0.026180         0.084563
# std            0.352525         0.267198          0.327586         0.289415
# min           -0.802425        -0.653153         -0.663480        -0.791781
# 25%                 NaN              NaN               NaN              NaN
# 50%                 NaN              NaN               NaN              NaN
# 75%                 NaN              NaN               NaN              NaN
# max            1.289454         0.756306          1.045373         0.894966
#
#        6_mean_edfa_math  7_mean_edfa_ela  7_mean_edfa_math  8_mean_edfa_ela  \
# count        219.000000       226.000000        226.000000       228.000000
# mean           0.054989         0.012370          0.019314         0.049950
# std            0.343802         0.291672          0.360863         0.280918
# min           -0.827827        -0.748603         -0.795048        -0.691615
# 25%                 NaN              NaN               NaN              NaN
# 50%                 NaN              NaN               NaN              NaN
# 75%                 NaN              NaN               NaN              NaN
# max            0.897513         0.996598          1.454810         1.058775
#
#        8_mean_edfa_math
# count        229.000000
# mean           0.037101
# std            0.334971
# min           -0.802230
# 25%                 NaN
# 50%                 NaN
# 75%                 NaN
# max            1.314681
#
# [8 rows x 51 columns]

# %%
data.corr()
# Out:
#                              elem_nutr_gen_atm  mid_nutr_gen_atm  \
# elem_nutr_gen_atm                     1.000000          0.693589
# mid_nutr_gen_atm                      0.693589          1.000000
# hs_nutr_gen_atm                       0.291288          0.251123
# elem_nutr_bkfst                       0.143740          0.032878
# mid_nutr_bkfst                        0.132659          0.061135
# hs_nutr_bkfst                         0.185656          0.074427
# elem_nutr_lunch                       0.068667          0.008011
# mid_nutr_lunch                        0.050501          0.019324
# hs_nutr_lunch                         0.085323          0.025714
# hs_nutr_vend                          0.034622          0.019284
# elem_nutr_sch_day                     0.062104         -0.053492
# mid_nutr_sch_day                     -0.001984         -0.020098
# hs_nutr_sch_day                       0.056548         -0.015044
# elem_ne_gen_guide_and_class           0.210218          0.100705
# mid_ne_gen_guide_and_class            0.167983          0.095694
# hs_ne_gen_guide_and_class             0.175772          0.086869
# elem_ne_cafeteria                     0.108874         -0.016293
# mid_ne_cafeteria                      0.089358         -0.022122
# hs_ne_cafeteria                       0.074221         -0.045727
# elem_ne_events_dur_sch_day            0.026134          0.031534
# mid_ne_events_dur_sch_day            -0.010843          0.015132
# elem_ne_fam_comm                      0.020096         -0.049437
# mid_ne_fam_comm                       0.014445         -0.046794
# hs_ne_fam_comm                       -0.002102         -0.070261
# elem_ne_staff_well                    0.016890         -0.034404
# mid_ne_staff_well                     0.046786         -0.015109
# hs_ne_staff_well                      0.017037         -0.025084
# elem_pa_gen_guide_pe_class            0.064212          0.033570
# mid_pa_gen_guide_pe_class             0.110333          0.053359
# hs_pa_gen_guide_pe_class              0.023811          0.054070
# elem_pa_thru_day                      0.105632          0.069578
# mid_pa_thru_day                       0.073826          0.045387
# hs_pa_thru_day                        0.113971          0.109379
# mid_pa_punish                         0.094195         -0.052163
# hs_pa_punish                          0.091430         -0.029658
# elem_pa_recess                       -0.046525         -0.062115
# elem_pa_fam_comm                      0.035366          0.023288
# mid_pa_fam_comm                      -0.030422         -0.029556
# hs_pa_fam_comm                       -0.058315         -0.073065
# 3_mean_edfa_ela                      -0.121776          0.002018
# 3_mean_edfa_math                     -0.029541         -0.003487
# 4_mean_edfa_ela                      -0.075379         -0.011166
# 4_mean_edfa_math                     -0.133176         -0.053579
# 5_mean_edfa_ela                       0.035466          0.040066
# 5_mean_edfa_math                      0.009830         -0.040003
# 6_mean_edfa_ela                      -0.069675         -0.017221
# 6_mean_edfa_math                     -0.088132         -0.102828
# 7_mean_edfa_ela                      -0.107376         -0.094132
# 7_mean_edfa_math                     -0.044730         -0.030544
# 8_mean_edfa_ela                      -0.075058         -0.044467
# 8_mean_edfa_math                     -0.064687         -0.025445
#
#                              hs_nutr_gen_atm  elem_nutr_bkfst  mid_nutr_bkfst  \
# elem_nutr_gen_atm                   0.291288         0.143740        0.132659
# mid_nutr_gen_atm                    0.251123         0.032878        0.061135
# hs_nutr_gen_atm                     1.000000         0.097253        0.092451
# elem_nutr_bkfst                     0.097253         1.000000        0.939147
# mid_nutr_bkfst                      0.092451         0.939147        1.000000
# hs_nutr_bkfst                       0.076557         0.950840        0.980346
# elem_nutr_lunch                     0.074447         0.466638        0.520349
# mid_nutr_lunch                      0.059443         0.456470        0.495636
# hs_nutr_lunch                       0.046372         0.439681        0.511552
# hs_nutr_vend                        0.123133         0.270776        0.331903
# elem_nutr_sch_day                   0.105916         0.187364        0.205583
# mid_nutr_sch_day                    0.115023         0.171813        0.178552
# hs_nutr_sch_day                     0.126738         0.261187        0.222002
# elem_ne_gen_guide_and_class         0.134370         0.270202        0.265339
# mid_ne_gen_guide_and_class          0.114394         0.227468        0.208375
# hs_ne_gen_guide_and_class           0.183397         0.223488        0.221711
# elem_ne_cafeteria                   0.129280         0.300604        0.288018
# mid_ne_cafeteria                    0.114319         0.253331        0.238613
# hs_ne_cafeteria                     0.114536         0.215108        0.212351
# elem_ne_events_dur_sch_day          0.016454         0.230353        0.242551
# mid_ne_events_dur_sch_day           0.033767         0.210391        0.209018
# elem_ne_fam_comm                    0.016886         0.288059        0.289390
# mid_ne_fam_comm                     0.011221         0.283762        0.276011
# hs_ne_fam_comm                      0.031181         0.219478        0.232559
# elem_ne_staff_well                 -0.004413         0.238875        0.298654
# mid_ne_staff_well                  -0.019514         0.272933        0.293598
# hs_ne_staff_well                    0.022279         0.205984        0.306156
# elem_pa_gen_guide_pe_class          0.015568         0.129401        0.121854
# mid_pa_gen_guide_pe_class           0.084595         0.034802        0.032480
# hs_pa_gen_guide_pe_class            0.057458         0.093008        0.065281
# elem_pa_thru_day                    0.104317         0.180704        0.189748
# mid_pa_thru_day                     0.062781         0.157584        0.148774
# hs_pa_thru_day                      0.085081         0.133841        0.152333
# mid_pa_punish                       0.124106         0.018085        0.045379
# hs_pa_punish                        0.085549         0.019442        0.051359
# elem_pa_recess                      0.032548         0.123682        0.146805
# elem_pa_fam_comm                    0.068702         0.152257        0.158578
# mid_pa_fam_comm                     0.069067         0.141582        0.143200
# hs_pa_fam_comm                      0.091183         0.088654        0.111873
# 3_mean_edfa_ela                     0.044502        -0.041413       -0.077480
# 3_mean_edfa_math                    0.051379         0.013494       -0.023477
# 4_mean_edfa_ela                     0.107204        -0.068182       -0.089004
# 4_mean_edfa_math                    0.115020        -0.066144       -0.092168
# 5_mean_edfa_ela                     0.102859        -0.033796       -0.037066
# 5_mean_edfa_math                    0.092118         0.003343        0.019319
# 6_mean_edfa_ela                     0.127223        -0.078366       -0.101314
# 6_mean_edfa_math                    0.104045        -0.048565       -0.061371
# 7_mean_edfa_ela                     0.098116        -0.062372       -0.032116
# 7_mean_edfa_math                    0.158033        -0.043203       -0.013620
# 8_mean_edfa_ela                     0.127156        -0.093704       -0.135399
# 8_mean_edfa_math                    0.106235        -0.048090       -0.085198
#
#                              hs_nutr_bkfst  elem_nutr_lunch  mid_nutr_lunch  \
# elem_nutr_gen_atm                 0.185656         0.068667        0.050501
# mid_nutr_gen_atm                  0.074427         0.008011        0.019324
# hs_nutr_gen_atm                   0.076557         0.074447        0.059443
# elem_nutr_bkfst                   0.950840         0.466638        0.456470
# mid_nutr_bkfst                    0.980346         0.520349        0.495636
# hs_nutr_bkfst                     1.000000         0.479073        0.480055
# elem_nutr_lunch                   0.479073         1.000000        0.951612
# mid_nutr_lunch                    0.480055         0.951612        1.000000
# hs_nutr_lunch                     0.463236         0.929815        0.973147
# hs_nutr_vend                      0.295613         0.430808        0.435962
# elem_nutr_sch_day                 0.225146         0.310713        0.271793
# mid_nutr_sch_day                  0.189626         0.300148        0.261736
# hs_nutr_sch_day                   0.246319         0.305248        0.268593
# elem_ne_gen_guide_and_class       0.299201         0.226511        0.202426
# mid_ne_gen_guide_and_class        0.243134         0.214142        0.216459
# hs_ne_gen_guide_and_class         0.232024         0.190620        0.177852
# elem_ne_cafeteria                 0.302001         0.276599        0.279178
# mid_ne_cafeteria                  0.258810         0.286440        0.290194
# hs_ne_cafeteria                   0.201118         0.266270        0.263877
# elem_ne_events_dur_sch_day        0.219753         0.232952        0.220153
# mid_ne_events_dur_sch_day         0.207124         0.249479        0.252614
# elem_ne_fam_comm                  0.265056         0.290761        0.269038
# mid_ne_fam_comm                   0.276352         0.284280        0.275472
# hs_ne_fam_comm                    0.216998         0.272745        0.257515
# elem_ne_staff_well                0.255964         0.265697        0.251481
# mid_ne_staff_well                 0.302786         0.235406        0.241972
# hs_ne_staff_well                  0.263083         0.276315        0.262019
# elem_pa_gen_guide_pe_class        0.107694         0.168714        0.124814
# mid_pa_gen_guide_pe_class         0.039084         0.099658        0.072451
# hs_pa_gen_guide_pe_class          0.080851         0.146825        0.138397
# elem_pa_thru_day                  0.175855         0.164009        0.187877
# mid_pa_thru_day                   0.136437         0.155706        0.144470
# hs_pa_thru_day                    0.126996         0.155255        0.140444
# mid_pa_punish                     0.046941        -0.016529       -0.013875
# hs_pa_punish                      0.032203         0.006254        0.025155
# elem_pa_recess                    0.124709         0.110972        0.085517
# elem_pa_fam_comm                  0.133673         0.177082        0.187864
# mid_pa_fam_comm                   0.156652         0.187797        0.198410
# hs_pa_fam_comm                    0.119965         0.152331        0.189428
# 3_mean_edfa_ela                  -0.096849        -0.155519       -0.186070
# 3_mean_edfa_math                 -0.036898        -0.069510       -0.092504
# 4_mean_edfa_ela                  -0.118683        -0.169001       -0.191148
# 4_mean_edfa_math                 -0.130028        -0.191902       -0.214861
# 5_mean_edfa_ela                  -0.040930        -0.003223       -0.058569
# 5_mean_edfa_math                  0.011697         0.039081       -0.038446
# 6_mean_edfa_ela                  -0.121552        -0.033586       -0.065016
# 6_mean_edfa_math                 -0.093957        -0.055765       -0.127557
# 7_mean_edfa_ela                  -0.054826        -0.044958       -0.078715
# 7_mean_edfa_math                 -0.041916        -0.058608       -0.065602
# 8_mean_edfa_ela                  -0.103963        -0.063877       -0.120558
# 8_mean_edfa_math                 -0.078143        -0.041485       -0.085133
#
#                              hs_nutr_lunch  hs_nutr_vend        ...         \
# elem_nutr_gen_atm                 0.085323      0.034622        ...
# mid_nutr_gen_atm                  0.025714      0.019284        ...
# hs_nutr_gen_atm                   0.046372      0.123133        ...
# elem_nutr_bkfst                   0.439681      0.270776        ...
# mid_nutr_bkfst                    0.511552      0.331903        ...
# hs_nutr_bkfst                     0.463236      0.295613        ...
# elem_nutr_lunch                   0.929815      0.430808        ...
# mid_nutr_lunch                    0.973147      0.435962        ...
# hs_nutr_lunch                     1.000000      0.448163        ...
# hs_nutr_vend                      0.448163      1.000000        ...
# elem_nutr_sch_day                 0.255379      0.373318        ...
# mid_nutr_sch_day                  0.242621      0.354808        ...
# hs_nutr_sch_day                   0.245460      0.359582        ...
# elem_ne_gen_guide_and_class       0.210017      0.203592        ...
# mid_ne_gen_guide_and_class        0.214104      0.124118        ...
# hs_ne_gen_guide_and_class         0.172967      0.124009        ...
# elem_ne_cafeteria                 0.287931      0.270717        ...
# mid_ne_cafeteria                  0.278120      0.297749        ...
# hs_ne_cafeteria                   0.268355      0.311575        ...
# elem_ne_events_dur_sch_day        0.224438      0.180152        ...
# mid_ne_events_dur_sch_day         0.208036      0.149180        ...
# elem_ne_fam_comm                  0.297975      0.260382        ...
# mid_ne_fam_comm                   0.303885      0.235787        ...
# hs_ne_fam_comm                    0.270778      0.253245        ...
# elem_ne_staff_well                0.293779      0.174096        ...
# mid_ne_staff_well                 0.266519      0.173016        ...
# hs_ne_staff_well                  0.293055      0.217549        ...
# elem_pa_gen_guide_pe_class        0.112817      0.144192        ...
# mid_pa_gen_guide_pe_class         0.060912      0.052254        ...
# hs_pa_gen_guide_pe_class          0.111838      0.071939        ...
# elem_pa_thru_day                  0.191673      0.195277        ...
# mid_pa_thru_day                   0.145051      0.169890        ...
# hs_pa_thru_day                    0.148791      0.134309        ...
# mid_pa_punish                    -0.020314      0.123666        ...
# hs_pa_punish                      0.026203      0.148278        ...
# elem_pa_recess                    0.060629      0.037368        ...
# elem_pa_fam_comm                  0.188210      0.171258        ...
# mid_pa_fam_comm                   0.184485      0.177134        ...
# hs_pa_fam_comm                    0.154234      0.156413        ...
# 3_mean_edfa_ela                  -0.188462     -0.202702        ...
# 3_mean_edfa_math                 -0.093088     -0.114722        ...
# 4_mean_edfa_ela                  -0.183577     -0.175496        ...
# 4_mean_edfa_math                 -0.196308     -0.152683        ...
# 5_mean_edfa_ela                  -0.046764     -0.068962        ...
# 5_mean_edfa_math                 -0.016313     -0.073360        ...
# 6_mean_edfa_ela                  -0.087520     -0.140649        ...
# 6_mean_edfa_math                 -0.120917     -0.058264        ...
# 7_mean_edfa_ela                  -0.070683     -0.102156        ...
# 7_mean_edfa_math                 -0.060512     -0.104503        ...
# 8_mean_edfa_ela                  -0.114175     -0.144958        ...
# 8_mean_edfa_math                 -0.083953     -0.125227        ...
#
#                              4_mean_edfa_ela  4_mean_edfa_math  \
# elem_nutr_gen_atm                  -0.075379         -0.133176
# mid_nutr_gen_atm                   -0.011166         -0.053579
# hs_nutr_gen_atm                     0.107204          0.115020
# elem_nutr_bkfst                    -0.068182         -0.066144
# mid_nutr_bkfst                     -0.089004         -0.092168
# hs_nutr_bkfst                      -0.118683         -0.130028
# elem_nutr_lunch                    -0.169001         -0.191902
# mid_nutr_lunch                     -0.191148         -0.214861
# hs_nutr_lunch                      -0.183577         -0.196308
# hs_nutr_vend                       -0.175496         -0.152683
# elem_nutr_sch_day                   0.006855         -0.012760
# mid_nutr_sch_day                   -0.021207         -0.026878
# hs_nutr_sch_day                    -0.010838         -0.033330
# elem_ne_gen_guide_and_class         0.090628          0.006702
# mid_ne_gen_guide_and_class          0.081134          0.007342
# hs_ne_gen_guide_and_class           0.096541          0.061824
# elem_ne_cafeteria                   0.003453          0.001235
# mid_ne_cafeteria                   -0.063234          0.003551
# hs_ne_cafeteria                    -0.039294          0.020865
# elem_ne_events_dur_sch_day         -0.021382         -0.039220
# mid_ne_events_dur_sch_day           0.009211          0.008915
# elem_ne_fam_comm                    0.056139          0.073510
# mid_ne_fam_comm                     0.009002          0.020912
# hs_ne_fam_comm                      0.026914          0.040927
# elem_ne_staff_well                  0.086390          0.071592
# mid_ne_staff_well                   0.047539          0.026423
# hs_ne_staff_well                    0.043643          0.047130
# elem_pa_gen_guide_pe_class          0.043089         -0.024221
# mid_pa_gen_guide_pe_class           0.046202         -0.004759
# hs_pa_gen_guide_pe_class           -0.003223          0.040525
# elem_pa_thru_day                    0.016153         -0.027083
# mid_pa_thru_day                     0.038738          0.009702
# hs_pa_thru_day                      0.005173         -0.021582
# mid_pa_punish                       0.191769          0.119690
# hs_pa_punish                        0.130311          0.082764
# elem_pa_recess                      0.014132          0.065621
# elem_pa_fam_comm                    0.050725          0.044885
# mid_pa_fam_comm                     0.048833          0.059108
# hs_pa_fam_comm                      0.005953         -0.023206
# 3_mean_edfa_ela                     0.570076          0.418054
# 3_mean_edfa_math                    0.427975          0.361683
# 4_mean_edfa_ela                     1.000000          0.792255
# 4_mean_edfa_math                    0.792255          1.000000
# 5_mean_edfa_ela                     0.457778          0.377519
# 5_mean_edfa_math                    0.376190          0.375887
# 6_mean_edfa_ela                     0.419737          0.328052
# 6_mean_edfa_math                    0.403004          0.413638
# 7_mean_edfa_ela                     0.370594          0.307822
# 7_mean_edfa_math                    0.323517          0.229008
# 8_mean_edfa_ela                     0.411641          0.332162
# 8_mean_edfa_math                    0.372963          0.270373
#
#                              5_mean_edfa_ela  5_mean_edfa_math  \
# elem_nutr_gen_atm                   0.035466          0.009830
# mid_nutr_gen_atm                    0.040066         -0.040003
# hs_nutr_gen_atm                     0.102859          0.092118
# elem_nutr_bkfst                    -0.033796          0.003343
# mid_nutr_bkfst                     -0.037066          0.019319
# hs_nutr_bkfst                      -0.040930          0.011697
# elem_nutr_lunch                    -0.003223          0.039081
# mid_nutr_lunch                     -0.058569         -0.038446
# hs_nutr_lunch                      -0.046764         -0.016313
# hs_nutr_vend                       -0.068962         -0.073360
# elem_nutr_sch_day                   0.037964          0.043367
# mid_nutr_sch_day                    0.010137          0.019559
# hs_nutr_sch_day                     0.038865          0.030987
# elem_ne_gen_guide_and_class         0.115923          0.070116
# mid_ne_gen_guide_and_class          0.101028          0.061288
# hs_ne_gen_guide_and_class           0.077329          0.068231
# elem_ne_cafeteria                   0.023408          0.008403
# mid_ne_cafeteria                   -0.041720          0.013390
# hs_ne_cafeteria                     0.021334          0.047625
# elem_ne_events_dur_sch_day          0.000203          0.016881
# mid_ne_events_dur_sch_day          -0.018379          0.026881
# elem_ne_fam_comm                    0.004811          0.059794
# mid_ne_fam_comm                    -0.042872          0.017396
# hs_ne_fam_comm                     -0.047956          0.041542
# elem_ne_staff_well                  0.040435          0.065952
# mid_ne_staff_well                   0.011206          0.019992
# hs_ne_staff_well                    0.019717          0.056540
# elem_pa_gen_guide_pe_class          0.007437          0.011879
# mid_pa_gen_guide_pe_class          -0.001936         -0.020290
# hs_pa_gen_guide_pe_class            0.020347         -0.044527
# elem_pa_thru_day                    0.019211         -0.043757
# mid_pa_thru_day                     0.052399         -0.055629
# hs_pa_thru_day                      0.096624         -0.023798
# mid_pa_punish                       0.120204          0.127298
# hs_pa_punish                        0.061815          0.068791
# elem_pa_recess                      0.096099          0.143158
# elem_pa_fam_comm                    0.105330          0.139352
# mid_pa_fam_comm                     0.045492          0.014016
# hs_pa_fam_comm                      0.000127         -0.020586
# 3_mean_edfa_ela                     0.444091          0.323943
# 3_mean_edfa_math                    0.415929          0.369445
# 4_mean_edfa_ela                     0.457778          0.376190
# 4_mean_edfa_math                    0.377519          0.375887
# 5_mean_edfa_ela                     1.000000          0.705138
# 5_mean_edfa_math                    0.705138          1.000000
# 6_mean_edfa_ela                     0.506738          0.323687
# 6_mean_edfa_math                    0.457516          0.421281
# 7_mean_edfa_ela                     0.397386          0.352379
# 7_mean_edfa_math                    0.328748          0.359166
# 8_mean_edfa_ela                     0.435958          0.267700
# 8_mean_edfa_math                    0.360144          0.299304
#
#                              6_mean_edfa_ela  6_mean_edfa_math  \
# elem_nutr_gen_atm                  -0.069675         -0.088132
# mid_nutr_gen_atm                   -0.017221         -0.102828
# hs_nutr_gen_atm                     0.127223          0.104045
# elem_nutr_bkfst                    -0.078366         -0.048565
# mid_nutr_bkfst                     -0.101314         -0.061371
# hs_nutr_bkfst                      -0.121552         -0.093957
# elem_nutr_lunch                    -0.033586         -0.055765
# mid_nutr_lunch                     -0.065016         -0.127557
# hs_nutr_lunch                      -0.087520         -0.120917
# hs_nutr_vend                       -0.140649         -0.058264
# elem_nutr_sch_day                   0.054264          0.027171
# mid_nutr_sch_day                    0.026368         -0.006261
# hs_nutr_sch_day                     0.025700          0.036999
# elem_ne_gen_guide_and_class        -0.019402          0.092050
# mid_ne_gen_guide_and_class          0.019504          0.093804
# hs_ne_gen_guide_and_class           0.056994          0.098029
# elem_ne_cafeteria                   0.004551          0.152060
# mid_ne_cafeteria                   -0.053459          0.093178
# hs_ne_cafeteria                    -0.029082          0.151177
# elem_ne_events_dur_sch_day         -0.031363          0.025347
# mid_ne_events_dur_sch_day          -0.099629         -0.055828
# elem_ne_fam_comm                   -0.041179          0.118752
# mid_ne_fam_comm                    -0.103992          0.001729
# hs_ne_fam_comm                     -0.075713          0.067276
# elem_ne_staff_well                 -0.063969          0.050456
# mid_ne_staff_well                  -0.076047          0.016945
# hs_ne_staff_well                   -0.038385          0.070684
# elem_pa_gen_guide_pe_class         -0.028680          0.011569
# mid_pa_gen_guide_pe_class          -0.016722          0.047194
# hs_pa_gen_guide_pe_class            0.015262          0.057848
# elem_pa_thru_day                   -0.051332          0.039105
# mid_pa_thru_day                    -0.026188          0.058324
# hs_pa_thru_day                     -0.022901          0.087941
# mid_pa_punish                       0.031763          0.116703
# hs_pa_punish                        0.011524          0.087630
# elem_pa_recess                      0.035564          0.128852
# elem_pa_fam_comm                   -0.013936          0.105202
# mid_pa_fam_comm                     0.051872          0.063751
# hs_pa_fam_comm                      0.053806          0.053609
# 3_mean_edfa_ela                     0.409187          0.320007
# 3_mean_edfa_math                    0.257577          0.234414
# 4_mean_edfa_ela                     0.419737          0.403004
# 4_mean_edfa_math                    0.328052          0.413638
# 5_mean_edfa_ela                     0.506738          0.457516
# 5_mean_edfa_math                    0.323687          0.421281
# 6_mean_edfa_ela                     1.000000          0.683217
# 6_mean_edfa_math                    0.683217          1.000000
# 7_mean_edfa_ela                     0.547545          0.490348
# 7_mean_edfa_math                    0.304945          0.405852
# 8_mean_edfa_ela                     0.497846          0.412382
# 8_mean_edfa_math                    0.428479          0.454859
#
#                              7_mean_edfa_ela  7_mean_edfa_math  \
# elem_nutr_gen_atm                  -0.107376         -0.044730
# mid_nutr_gen_atm                   -0.094132         -0.030544
# hs_nutr_gen_atm                     0.098116          0.158033
# elem_nutr_bkfst                    -0.062372         -0.043203
# mid_nutr_bkfst                     -0.032116         -0.013620
# hs_nutr_bkfst                      -0.054826         -0.041916
# elem_nutr_lunch                    -0.044958         -0.058608
# mid_nutr_lunch                     -0.078715         -0.065602
# hs_nutr_lunch                      -0.070683         -0.060512
# hs_nutr_vend                       -0.102156         -0.104503
# elem_nutr_sch_day                  -0.020891         -0.017555
# mid_nutr_sch_day                   -0.040283         -0.038621
# hs_nutr_sch_day                    -0.034019         -0.024932
# elem_ne_gen_guide_and_class         0.005321          0.013881
# mid_ne_gen_guide_and_class          0.049251          0.056095
# hs_ne_gen_guide_and_class           0.032796          0.042287
# elem_ne_cafeteria                   0.002446          0.060339
# mid_ne_cafeteria                   -0.012784          0.011289
# hs_ne_cafeteria                    -0.020448          0.023971
# elem_ne_events_dur_sch_day         -0.140391         -0.025712
# mid_ne_events_dur_sch_day          -0.194721         -0.029327
# elem_ne_fam_comm                   -0.087890          0.025136
# mid_ne_fam_comm                    -0.113341         -0.010211
# hs_ne_fam_comm                     -0.091867         -0.023602
# elem_ne_staff_well                 -0.039773          0.078414
# mid_ne_staff_well                  -0.069733          0.058227
# hs_ne_staff_well                   -0.044349          0.032797
# elem_pa_gen_guide_pe_class         -0.092002         -0.124980
# mid_pa_gen_guide_pe_class          -0.055050          0.010433
# hs_pa_gen_guide_pe_class           -0.079081         -0.067269
# elem_pa_thru_day                   -0.034452         -0.023311
# mid_pa_thru_day                    -0.013432          0.018952
# hs_pa_thru_day                     -0.020018          0.016193
# mid_pa_punish                       0.129887          0.172107
# hs_pa_punish                        0.063223          0.115591
# elem_pa_recess                      0.018552          0.069576
# elem_pa_fam_comm                   -0.002746          0.129413
# mid_pa_fam_comm                     0.053719          0.051962
# hs_pa_fam_comm                      0.063955          0.075841
# 3_mean_edfa_ela                     0.389168          0.172679
# 3_mean_edfa_math                    0.324995          0.187482
# 4_mean_edfa_ela                     0.370594          0.323517
# 4_mean_edfa_math                    0.307822          0.229008
# 5_mean_edfa_ela                     0.397386          0.328748
# 5_mean_edfa_math                    0.352379          0.359166
# 6_mean_edfa_ela                     0.547545          0.304945
# 6_mean_edfa_math                    0.490348          0.405852
# 7_mean_edfa_ela                     1.000000          0.645177
# 7_mean_edfa_math                    0.645177          1.000000
# 8_mean_edfa_ela                     0.673492          0.429917
# 8_mean_edfa_math                    0.503360          0.633212
#
#                              8_mean_edfa_ela  8_mean_edfa_math
# elem_nutr_gen_atm                  -0.075058         -0.064687
# mid_nutr_gen_atm                   -0.044467         -0.025445
# hs_nutr_gen_atm                     0.127156          0.106235
# elem_nutr_bkfst                    -0.093704         -0.048090
# mid_nutr_bkfst                     -0.135399         -0.085198
# hs_nutr_bkfst                      -0.103963         -0.078143
# elem_nutr_lunch                    -0.063877         -0.041485
# mid_nutr_lunch                     -0.120558         -0.085133
# hs_nutr_lunch                      -0.114175         -0.083953
# hs_nutr_vend                       -0.144958         -0.125227
# elem_nutr_sch_day                   0.020470          0.023207
# mid_nutr_sch_day                   -0.029773         -0.011041
# hs_nutr_sch_day                    -0.008848          0.031974
# elem_ne_gen_guide_and_class         0.032910          0.031568
# mid_ne_gen_guide_and_class          0.082530          0.069122
# hs_ne_gen_guide_and_class           0.068624          0.056267
# elem_ne_cafeteria                   0.022924          0.095950
# mid_ne_cafeteria                    0.023118          0.071449
# hs_ne_cafeteria                     0.048989          0.097284
# elem_ne_events_dur_sch_day         -0.077166         -0.039472
# mid_ne_events_dur_sch_day          -0.121766         -0.068982
# elem_ne_fam_comm                   -0.006706          0.070626
# mid_ne_fam_comm                    -0.037910          0.024589
# hs_ne_fam_comm                     -0.051743          0.023805
# elem_ne_staff_well                 -0.085919          0.014034
# mid_ne_staff_well                  -0.113117         -0.015282
# hs_ne_staff_well                   -0.114255         -0.023323
# elem_pa_gen_guide_pe_class         -0.041110         -0.031165
# mid_pa_gen_guide_pe_class          -0.035376          0.019691
# hs_pa_gen_guide_pe_class           -0.076705         -0.014329
# elem_pa_thru_day                   -0.075439          0.021927
# mid_pa_thru_day                    -0.019102          0.094961
# hs_pa_thru_day                     -0.007961          0.098483
# mid_pa_punish                       0.077652          0.053433
# hs_pa_punish                        0.021434          0.027513
# elem_pa_recess                      0.029446          0.090759
# elem_pa_fam_comm                    0.018962          0.019044
# mid_pa_fam_comm                     0.055942          0.013626
# hs_pa_fam_comm                      0.008300         -0.006493
# 3_mean_edfa_ela                     0.361143          0.304956
# 3_mean_edfa_math                    0.310919          0.263232
# 4_mean_edfa_ela                     0.411641          0.372963
# 4_mean_edfa_math                    0.332162          0.270373
# 5_mean_edfa_ela                     0.435958          0.360144
# 5_mean_edfa_math                    0.267700          0.299304
# 6_mean_edfa_ela                     0.497846          0.428479
# 6_mean_edfa_math                    0.412382          0.454859
# 7_mean_edfa_ela                     0.673492          0.503360
# 7_mean_edfa_math                    0.429917          0.633212
# 8_mean_edfa_ela                     1.000000          0.641723
# 8_mean_edfa_math                    0.641723          1.000000
#
# [51 rows x 51 columns]

# %%
#Not sure how I can see everything on my correlation matrix, so I'll just get started.

import numpy as np
from sklearn.linear_model import LinearRegression
import statsmodels.formula.api as smf

# %%
my_list = data.columns.values
for i in my_list:
    print i
# Out:
# District Name
# elem_nutr_gen_atm
# mid_nutr_gen_atm
# hs_nutr_gen_atm
# elem_nutr_bkfst
# mid_nutr_bkfst
# hs_nutr_bkfst
# elem_nutr_lunch
# mid_nutr_lunch
# hs_nutr_lunch
# hs_nutr_vend
# elem_nutr_sch_day
# mid_nutr_sch_day
# hs_nutr_sch_day
# elem_ne_gen_guide_and_class
# mid_ne_gen_guide_and_class
# hs_ne_gen_guide_and_class
# elem_ne_cafeteria
# mid_ne_cafeteria
# hs_ne_cafeteria
# elem_ne_events_dur_sch_day
# mid_ne_events_dur_sch_day
# hs_ne_events_dur_sch_day
# elem_ne_fam_comm
# mid_ne_fam_comm
# hs_ne_fam_comm
# elem_ne_staff_well
# mid_ne_staff_well
# hs_ne_staff_well
# elem_pa_gen_guide_pe_class
# mid_pa_gen_guide_pe_class
# hs_pa_gen_guide_pe_class
# elem_pa_thru_day
# mid_pa_thru_day
# hs_pa_thru_day
# elem_pa_punish
# mid_pa_punish
# hs_pa_punish
# elem_pa_recess
# elem_pa_fam_comm
# mid_pa_fam_comm
# hs_pa_fam_comm
# 3_mean_edfa_ela
# 3_mean_edfa_math
# 4_mean_edfa_ela
# 4_mean_edfa_math
# 5_mean_edfa_ela
# 5_mean_edfa_math
# 6_mean_edfa_ela
# 6_mean_edfa_math
# 7_mean_edfa_ela
# 7_mean_edfa_math
# 8_mean_edfa_ela
# 8_mean_edfa_math

# %%
#address NaN values in 'elem_nutr_gen_atm'

DataDroppedElemNutrGenAtm = data.dropna(subset = ['elem_nutr_gen_atm'])

# %%
X1 = DataDroppedElemNutrGenAtm[['elem_nutr_bkfst', 
                                'elem_nutr_lunch', 
                                'elem_nutr_sch_day',
                                'elem_ne_gen_guide_and_class', 
                                'elem_ne_cafeteria', 
                                'elem_ne_events_dur_sch_day', 
                                'elem_ne_fam_comm',
                                'elem_ne_staff_well', 
                                'elem_pa_gen_guide_pe_class',
                                'elem_pa_thru_day', 
                                'elem_pa_recess']]
y1 = DataDroppedElemNutrGenAtm['elem_nutr_gen_atm']

lm1 = smf.ols(formula = 'y1 ~ X1', data = DataDroppedElemNutrGenAtm).fit()

print zip(('intercept',
           'elem_nutr_bkfst', 
           'elem_nutr_lunch', 
           'elem_nutr_sch_day',
           'elem_ne_gen_guide_and_class', 
           'elem_ne_cafeteria', 
           'elem_ne_events_dur_sch_day', 
           'elem_ne_fam_comm',
           'elem_ne_staff_well', 
           'elem_pa_gen_guide_pe_class',
           'elem_pa_thru_day', 
           'elem_pa_recess'), lm1.pvalues)
# Out:
# [('intercept', 3.5937604686025699e-40), ('elem_nutr_bkfst', 0.28109115203038981), ('elem_nutr_lunch', 0.85789473546489847), ('elem_nutr_sch_day', 0.87369618454343156), ('elem_ne_gen_guide_and_class', 0.0060266153523904709), ('elem_ne_cafeteria', 0.181891076956993), ('elem_ne_events_dur_sch_day', 0.93281303973223806), ('elem_ne_fam_comm', 0.053272371954979018), ('elem_ne_staff_well', 0.8192497613950166), ('elem_pa_gen_guide_pe_class', 0.83928572021819892), ('elem_pa_thru_day', 0.60705628330694295), ('elem_pa_recess', 0.042193590417989993)]

# %%
#Just two variables are significant (which makes sense since I feel like my variables are fairly independent)
#significant variables: elem_ne_gen_guide_and_class, elem_pa_recess

X2 = DataDroppedElemNutrGenAtm[['elem_ne_gen_guide_and_class',
                               'elem_pa_recess']]
y2 = DataDroppedElemNutrGenAtm['elem_nutr_gen_atm']

lm2 = smf.ols(formula = 'y2 ~ X2', data = DataDroppedElemNutrGenAtm).fit()

print lm2.pvalues
# Out:
# Intercept    1.477756e-101
# X2[0]         3.034407e-04
# X2[1]         9.770236e-02
# dtype: float64

# %%
#followed example from lecture 6, but clearly am missing something... ideas?

lm = LinearRegression()

lm.fit(X2, y2)

X3 = data[['elem_ne_gen_guide_and_class',
          'elem_pa_recess']]

data['elem_nutr_gen_atm_predict'] = lm.predict(X3)
data['elem_nutr_gen_atm'].fillna(value = data['elem_nutr_gen_atm_predict'], inplace = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-3fc54f654b47> in <module>()
#       3 lm = LinearRegression()
#       4
# ----> 5 lm.fit(X2, y2)
#       6
#       7 X3 = data[['elem_ne_gen_guide_and_class',
#
# C:\Users\Allison\Anaconda2\lib\site-packages\sklearn\linear_model\base.pyc in fit(self, X, y, sample_weight)
#     425         n_jobs_ = self.n_jobs
#     426         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 427                          y_numeric=True, multi_output=True)
#     428
#     429         if ((sample_weight is not None) and np.atleast_1d(sample_weight).ndim > 1):
#
# C:\Users\Allison\Anaconda2\lib\site-packages\sklearn\utils\validation.pyc in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     508     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
#     509                     ensure_2d, allow_nd, ensure_min_samples,
# --> 510                     ensure_min_features, warn_on_dtype, estimator)
#     511     if multi_output:
#     512         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# C:\Users\Allison\Anaconda2\lib\site-packages\sklearn\utils\validation.pyc in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     396                              % (array.ndim, estimator_name))
#     397         if force_all_finite:
# --> 398             _assert_all_finite(array)
#     399
#     400     shape_repr = _shape_repr(array.shape)
#
# C:\Users\Allison\Anaconda2\lib\site-packages\sklearn\utils\validation.pyc in _assert_all_finite(X)
#      52             and not np.isfinite(X).all()):
#      53         raise ValueError("Input contains NaN, infinity"
# ---> 54                          " or a value too large for %r." % X.dtype)
#      55
#      56
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
